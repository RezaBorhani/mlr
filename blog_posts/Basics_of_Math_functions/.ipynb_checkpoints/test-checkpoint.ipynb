# %%
# run this cell to import all necessary libraries for the notebook experiments
import sys
sys.path.append('../../')
from mlrefined_libraries import basics_library as baslib
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# create an animation showing the origin of the sine and cosine functions
baslib.trig_hyper_visualizer.norm(num_frames=20)
# Out:
# starting animation rendering...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1a80e7b2f282> in <module>()
#       1 # create an animation showing the origin of the sine and cosine functions
# ----> 2 baslib.trig_hyper_visualizer.norm(num_frames=20)
#
# ~/Dropbox/github_repos/mlrefined/mlrefined_libraries/basics_library/trig_hyper_visualizer.py in norm(**kwargs)
#     283         return artist,
#     284
# --> 285     anim = animation.FuncAnimation(fig, animate ,frames=num_frames, interval=num_frames, blit=True)
#     286
#     287     return(anim)
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, **kwargs)
#    1510         self._save_seq = []
#    1511
# -> 1512         TimedAnimation.__init__(self, fig, **kwargs)
#    1513
#    1514         # Need to reset the saved seq, since right now it will contain data
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1277
#    1278         Animation.__init__(self, fig, event_source=event_source,
# -> 1279                            *args, **kwargs)
#    1280
#    1281     def _step(self, *args):
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in __init__(self, fig, event_source, blit)
#     867                                                       self._stop)
#     868         if self._blit:
# --> 869             self._setup_blit()
#     870
#     871     def _start(self, *args):
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in _setup_blit(self)
#    1159         self._resize_id = self._fig.canvas.mpl_connect('resize_event',
#    1160                                                        self._handle_resize)
# -> 1161         self._post_draw(None, self._blit)
#    1162
#    1163     def _handle_resize(self, *args):
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1123             self._blit_draw(self._drawn_artists, self._blit_cache)
#    1124         else:
# -> 1125             self._fig.canvas.draw_idle()
#    1126
#    1127     # The rest of the code in this class is to facilitate easy blitting
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2038         if not self._is_idle_drawing:
#    2039             with self._idle_draw_cntx():
# -> 2040                 self.draw(*args, **kwargs)
#    2041
#    2042     def draw_cursor(self, event):
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1149
#    1150         self._cachedRenderer = renderer
# -> 1151         self.canvas.draw_event(renderer)
#    1152
#    1153     def draw_artist(self, a):
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/backend_bases.py in draw_event(self, renderer)
#    1821         s = 'draw_event'
#    1822         event = DrawEvent(s, self, renderer)
# -> 1823         self.callbacks.process(s, event)
#    1824
#    1825     def resize_event(self):
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     552             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     553                 try:
# --> 554                     proxy(*args, **kwargs)
#     555                 except ReferenceError:
#     556                     self._remove_proxy(proxy)
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     414             mtd = self.func
#     415         # invoke the callable and return the result
# --> 416         return mtd(*args, **kwargs)
#     417
#     418     def __eq__(self, other):
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in _start(self, *args)
#     879
#     880         # Now do any initial draw
# --> 881         self._init_draw()
#     882
#     883         # Add our callback for stepping the animation and
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in _init_draw(self)
#    1538         # artists.
#    1539         if self._init_func is None:
# -> 1540             self._draw_frame(next(self.new_frame_seq()))
#    1541
#    1542         else:
#
# ~/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1560         # Call the func with framedata and args. If blitting is desired,
#    1561         # func needs to return a sequence of any artists that were modified.
# -> 1562         self._drawn_artists = self._func(framedata, *self._args)
#    1563         if self._blit:
#    1564             if self._drawn_artists is None:
#
# ~/Dropbox/github_repos/mlrefined/mlrefined_libraries/basics_library/trig_hyper_visualizer.py in animate(k)
#     251         # clear panels for next slide
#     252         ax1.cla()
# --> 253         ax2.cla()
#     254
#     255         # print rendering update
#
# NameError: name 'ax2' is not defined

# %%
# what function should we play with?  Defined in the next line.
f1 = lambda x: 2*np.sin(x) + 3*np.cos(0.1*x-1)
f2 = lambda x: np.sin(10*x)

# create an instance of the visualizer with this function
test = baslib.convex_function_addition_2d.visualizer()

# plot away
test.draw_it(g1 = f1, g2 = f2, num_frames = 50, min_range = -10, max_range = 5, title1='$f_1(x)$', title2='$f_2(x)$', title3='$w\,f_1(x)+(1-w)\,f_2(x)$')
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#     /* slider */
#     var elem = document.querySelector('input[type="range"]');
#
#     var rangeValue = function(){
#       var newValue = elem.value;
#       var target = document.querySelector('.value');
#       target.innerHTML = newValue;
#     }
#
#     elem.addEventListener("input", rangeValue);
#
#
#
# </script>
#
#
# <!-- slider -->
# <link rel="stylesheet" type="text/css" href="../../mlrefined_libraries/JSAnimation_slider_only/icons/mystyle.css">
#
# <div class= "animation" align="center">
#     <img id="_anim_imgIWJSFGHBMHFPNGFJ">
#     <br>
#     <input class="range-slider__range" id="_anim_sliderIWJSFGHBMHFPNGFJ" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" oninput="animIWJSFGHBMHFPNGFJ.set_frame(parseInt(this.value));"></input>
#     <!-- <div class="value">0</div> -->
#     <br><br>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgIWJSFGHBMHFPNGFJ";
#     var slider_id = "_anim_sliderIWJSFGHBMHFPNGFJ";
#     var loop_select_id = "_anim_loop_selectIWJSFGHBMHFPNGFJ";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animIWJSFGHBMHFPNGFJ = new Animation(frames, img_id, slider_id, 50, loop_select_id);
#     }, 0);
#   })()
# </script>
